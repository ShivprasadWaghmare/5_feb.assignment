# %% [markdown]
#    1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.
#    ans:In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines a set of attributes (data members)         and methods (functions) that the objects created from the class will have. An object, on the other hand, is an instance of a class – a concrete       realization of the class blueprint.
#
#    Example:
#
# Let's consider a class called "Car":
#
# python
# Copy code
# class Car:
#     def __init__(self, make, model):
#         self.make = make
#         self.model = model
#         self.speed = 0
#
#     def accelerate(self):
#         self.speed += 10
#
#     def brake(self):
#         self.speed -= 5
#
#     def display_info(self):
#         print(f"{self.make} {self.model} - Speed: {self.speed} km/h")
# Now, we can create objects (instances) of the "Car" class:
#
# python
# Copy code
# car1 = Car("Toyota", "Camry")
# car2 = Car("Ford", "Mustang")
#
# car1.accelerate()
# car1.display_info()
#
# car2.accelerate()
# car2.brake()
# car2.display_info()
# In this example, "Car" is the class with attributes like "make," "model," and "speed," and methods like "accelerate," "brake," and "display_info." The objects car1 and car2 are instances of the "Car" class, each having its own set of attributes and interacting with the defined methods.
#
#
#   2. Name the four pillars of OOPs.
#   ans:
#   1.Abstraction
#   2.Inheritance
#   3.Incapsulilation
#   4.polymorphism
#
#
#
#   3. Explain why the __init__() function is used. Give a suitable example.
# ans:The __init__() function in Python is a special method used in classes to initialize the object's attributes when an instance of the class is           created. It is called automatically when an object is instantiated.
#
#    class Car:
#     def __init__(self, make, model):
#         self.make = make
#         self.model = model
#
# # Creating an instance of the Car class
# my_car = Car(make='Toyota', model='Camry')
#
# # Accessing the initialized attributes
# print(my_car.make)  # Output: Toyota
# print(my_car.model)  # Output: Camry
# In this example, the __init__() method initializes the make and model attributes of the Car class when a new Car object (my_car) is created.
#
#
# 4. Why self is used in OOPs?
# ans:In object-oriented programming (OOP), the "self" keyword is used to refer to the instance of the class within the class itself. It allows access to the instance's attributes and methods, facilitating the manipulation and interaction with object-specific data and behavior.
# 5. What is inheritance? Give an example for each type of inheritance.
# ans:
# Inheritance is a concept in object-oriented programming where a new class (subclass or derived class) can inherit attributes and behaviors from an existing class (base class or parent class). This helps in reusing code and creating a hierarchy of classes.
#
# 1. **Single Inheritance:**
#    - Example:
#      ```python
#      class Animal:
#          def speak(self):
#              print("Animal speaks")
#
#      class Dog(Animal):
#          def bark(self):
#              print("Dog barks")
#
#      # Dog inherits from Animal, so it can use the speak method.
#      my_dog = Dog()
#      my_dog.speak()  # Output: Animal speaks
#      ```
#
# 2. **Multiple Inheritance:**
#    - Example:
#      ```python
#      class Flyable:
#          def fly(self):
#              print("Can fly")
#
#      class Swimmable:
#          def swim(self):
#              print("Can swim")
#
#      class Amphibian(Flyable, Swimmable):
#          pass
#
#      # Amphibian inherits from both Flyable and Swimmable.
#      amphibian = Amphibian()
#      amphibian.fly()  # Output: Can fly
#      amphibian.swim() # Output: Can swim
#      ```
#
# 3. **Multilevel Inheritance:**
#    - Example:
#      ```python
#      class Vehicle:
#          def start(self):
#              print("Vehicle started")
#
#      class Car(Vehicle):
#          def drive(self):
#              print("Car is being driven")
#
#      class SportsCar(Car):
#          def race(self):
#              print("Sports car is racing")
#
#      # SportsCar inherits from both Car and Vehicle.
#      my_sports_car = SportsCar()
#      my_sports_car.start()  # Output: Vehicle started
#      my_sports_car.drive()  # Output: Car is being driven
#      my_sports_car.race()   # Output: Sports car is racing
#      ```
#
# In each example:
# - The base class provides common functionalities.
# - The derived class inherits from the base class and may add new attributes or methods.
# - Objects of the derived class can use both the inherited and newly defined functionalities.
